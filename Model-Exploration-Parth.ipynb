# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ##### Create tables

# %%
merged_df = pd.read_pickle('data/merged_mean_data.pkl').fillna(0)
merged_df['gender.label'] = merged_df['gender.label'].apply(lambda label: 1 if label == 'male' else 0).apply(pd.to_numeric)

merged_df.head(5)
# Out:
#       psychopath,empath  punchable,loveable  arrogant,humble  \
# A1                 55.5                31.0             51.7
# A4                 16.9                18.9             20.9
# AD1                75.3                51.9             45.9
# AD7                44.8                38.1             29.0
# AHX1               48.6                57.0             33.9
#
#       selfish,altruistic  cruel,kind  vengeful,forgiving  quarrelsome,warm  \
# A1                  59.7        63.1                60.1              45.0
# A4                  29.4        26.2                27.5              25.1
# AD1                 61.5        68.2                64.9              40.4
# AD7                 40.8        77.5                73.0              64.4
# AHX1                25.0        48.1                60.2              19.7
#
#       impatient,patient  juvenile,mature  entitled,grateful  ...  \
# A1                 48.6             73.3               34.7  ...
# A4                 61.8             74.4                7.7  ...
# AD1                55.0             72.8               38.0  ...
# AD7                46.0             14.8               32.0  ...
# AHX1               28.7             22.5               31.5  ...
#
#       outsider,insider  industrial,domestic  complicated,simple  \
# A1                60.5                 29.6                52.7
# A4                41.7                 15.4                30.3
# AD1               44.1                 61.8                44.0
# AD7               12.1                 82.1                44.1
# AHX1              21.8                 47.2                22.2
#
#       literary,mathematical  slow,fast  careful,brave  race.label  \
# A1                     65.8       53.0           57.8       asian
# A4                     87.7       63.3           26.2       white
# AD1                    76.0       65.2           23.8       white
# AD7                    24.8       18.9           37.1       white
# AHX1                   25.0       66.5           60.8       white
#
#       race.confidence  gender.label  gender.confidence
# A1                1.0             1               1.00
# A4                1.0             1               0.94
# AD1               1.0             1               0.89
# AD7               1.0             1               1.00
# AHX1              1.0             1               0.92
#
# [5 rows x 364 columns]

# %%
merged_df.shape
# Out:
# (858, 364)

# %% [markdown]
# ##### Standardize index names

# %%
traits_columns = list(filter(lambda col: ',' in col, merged_df.columns.values))

print('Total Dual Traits:', len(traits_columns))
# Out:
# Total Dual Traits: 360

# %%
from sklearn.model_selection import KFold, train_test_split

def evaluate_classifier(label, model, classifier, X, y):
    
    k_fold = KFold(n_splits=5)
    
    total_accuracy = 0
    total_tries = 0
    
    for train_index, test_index in k_fold.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]

        classifier.fit(X_train, y_train)

        y_pred = classifier.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred, normalize=True)

        total_accuracy += accuracy
        total_tries += 1
        
    print(f'{label} Accuracy using {model}:', round(total_accuracy / total_tries, 4))

# %% [markdown]
# # Predict the Gender

# %%
from sklearn.linear_model import LassoCV, Ridge, RidgeClassifier, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# For gender prediction, we remove the 'masculine' label
gender_columns = list(filter(lambda trait: 'masculine' not in trait, traits_columns))
X = merged_df[gender_columns].values
y = merged_df['gender.label'].values


evaluate_classifier('Gender', 'Random Forest 2^8 estimators, Gini', RandomForestClassifier(n_estimators=2**8, criterion='gini'), X, y)
evaluate_classifier('Gender', 'Random Forest 2^8 estimators, Entropy', RandomForestClassifier(n_estimators=2**8, criterion='entropy'), X, y)
evaluate_classifier('Gender', 'Logistic Regression L2', LogisticRegression(penalty='l2', max_iter=5000), X, y)
evaluate_classifier('Gender', 'Ridge Classifier, alpha 0.1', RidgeClassifier(alpha=0.1), X, y)
evaluate_classifier('Gender', 'Decision Tree, vanilla ', DecisionTreeClassifier(), X, y)
# Out:
# Gender Accuracy using Random Forest 2^8 estimators, Gini: 0.8998
# Gender Accuracy using Random Forest 2^8 estimators, Entropy: 0.901
# Gender Accuracy using Logistic Regression L2: 0.9651
# Gender Accuracy using Ridge Classifier, alpha 0.1: 0.9616
# Gender Accuracy using Decision Tree, vanilla : 0.8555

# %%
merged_df['gender.label'].value_counts()
# Out:
# 1    577
# 0    281
# Name: gender.label, dtype: int64

# %% [markdown]
# # Predict the Race

# %%
from sklearn.linear_model import LassoCV, Ridge, RidgeClassifier, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.preprocessing import LabelEncoder

# For gender prediction, we remove the 'masculine' label
race_columns = list(traits_columns)
race_columns.append('gender.label')

y_encoder = LabelEncoder()

X = merged_df[race_columns].values
y = y_encoder.fit_transform(merged_df['race.label'])

evaluate_classifier('Race', 'Random Forest 2^8 estimators, Gini', RandomForestClassifier(n_estimators=2**8, criterion='gini'), X, y)
evaluate_classifier('Race', 'Random Forest 2^8 estimators, Entropy', RandomForestClassifier(n_estimators=2**8, criterion='entropy'), X, y)
evaluate_classifier('Race', 'Logistic Regression L2, 10000 iterations', LogisticRegression(penalty='l2', max_iter=10000), X, y)
evaluate_classifier('Race', 'Ridge Classifier, alpha 0.1 ', RidgeClassifier(alpha=0.1), X, y)
evaluate_classifier('Race', 'Decision Tree, vanilla ', DecisionTreeClassifier(), X, y)
# Out:
# Race Accuracy using Random Forest 2^8 estimators, Gini: 0.8531
# Race Accuracy using Random Forest 2^8 estimators, Entropy: 0.8543
# Race Accuracy using Logistic Regression L2, 10000 iterations: 0.7657
# Race Accuracy using Ridge Classifier, alpha 0.1 : 0.7669
# Race Accuracy using Decision Tree, vanilla : 0.7319

# %%
from sklearn import tree
from matplotlib import pyplot as plt

decision_tree_classifier = DecisionTreeClassifier(criterion='gini')  
decision_tree_classifier.fit(X, y)



fig = plt.figure(figsize=(100,40))
_ = tree.plot_tree(decision_tree_classifier, 
                   feature_names=race_columns,  
                   class_names=y_encoder.classes_,
                   filled=True,
                   label='all')

# %%
merged_df['race.label'].value_counts()['white'] / len(merged_df['race.label'])
# Out:
# 0.8543123543123543

# %%
merged_df['race.label'].value_counts()
# Out:
# white       733
# asian        82
# black        27
# hispanic     13
# indian        2
# mideast       1
# Name: race.label, dtype: int64

# %%
len(merged_df['race.label'])
# Out:
# 858

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\lenovo\anaconda3\lib\site-packages (0.8.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn) (0.16.0)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn) (0.24.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\lenovo\anaconda3\lib\site-packages (from imbalanced-learn) (1.18.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn) (2.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
merged_df
# Out:
#       psychopath,empath  punchable,loveable  arrogant,humble  \
# A1                 55.5                31.0             51.7
# A4                 16.9                18.9             20.9
# AD1                75.3                51.9             45.9
# AD7                44.8                38.1             29.0
# AHX1               48.6                57.0             33.9
# ...                 ...                 ...              ...
# Y5                 51.3                68.8             63.5
# Y6                 89.2                69.3             85.3
# Y8                 41.4                29.3             25.8
# Y9                 66.8                70.0             68.9
# ZL1                32.4                54.0             22.5
#
#       selfish,altruistic  cruel,kind  vengeful,forgiving  quarrelsome,warm  \
# A1                  59.7        63.1                60.1              45.0
# A4                  29.4        26.2                27.5              25.1
# AD1                 61.5        68.2                64.9              40.4
# AD7                 40.8        77.5                73.0              64.4
# AHX1                25.0        48.1                60.2              19.7
# ...                  ...         ...                 ...               ...
# Y5                  69.0        53.2                17.6              29.1
# Y6                  77.2        83.0                57.6              74.1
# Y8                  37.7        31.6                17.7              33.6
# Y9                  79.5        72.2                44.5              51.0
# ZL1                 39.6        55.8                25.8              28.2
#
#       impatient,patient  juvenile,mature  entitled,grateful  ...  \
# A1                 48.6             73.3               34.7  ...
# A4                 61.8             74.4                7.7  ...
# AD1                55.0             72.8               38.0  ...
# AD7                46.0             14.8               32.0  ...
# AHX1               28.7             22.5               31.5  ...
# ...                 ...              ...                ...  ...
# Y5                 33.1             63.2               86.8  ...
# Y6                 72.0             80.6               70.2  ...
# Y8                 60.2             61.6               30.5  ...
# Y9                 70.0             77.5               76.8  ...
# ZL1                10.8             29.4               44.1  ...
#
#       outsider,insider  industrial,domestic  complicated,simple  \
# A1                60.5                 29.6                52.7
# A4                41.7                 15.4                30.3
# AD1               44.1                 61.8                44.0
# AD7               12.1                 82.1                44.1
# AHX1              21.8                 47.2                22.2
# ...                ...                  ...                 ...
# Y5                32.5                 40.1                44.6
# Y6                19.9                 48.4                35.5
# Y8                43.0                 56.7                 8.0
# Y9                42.3                 38.0                76.4
# ZL1               18.3                 37.0                45.6
#
#       literary,mathematical  slow,fast  careful,brave  race.label  \
# A1                     65.8       53.0           57.8       asian
# A4                     87.7       63.3           26.2       white
# AD1                    76.0       65.2           23.8       white
# AD7                    24.8       18.9           37.1       white
# AHX1                   25.0       66.5           60.8       white
# ...                     ...        ...            ...         ...
# Y5                     61.4       79.4           93.4       white
# Y6                     27.9       71.9           63.6       asian
# Y8                     49.4       63.8           27.7       white
# Y9                     35.6       51.7           58.7       white
# ZL1                    33.1       75.3           85.6       white
#
#       race.confidence  gender.label  gender.confidence
# A1               1.00             1               1.00
# A4               1.00             1               0.94
# AD1              1.00             1               0.89
# AD7              1.00             1               1.00
# AHX1             1.00             1               0.92
# ...               ...           ...                ...
# Y5               1.00             1               1.00
# Y6               0.96             0               0.91
# Y8               1.00             1               0.98
# Y9               1.00             1               1.00
# ZL1              1.00             1               1.00
#
# [858 rows x 364 columns]

# %%
merged_df_cpy = merged_df.drop(['race.label', 'race.confidence', 'gender.label', 'gender.confidence'], axis = 1)

# %%
merged_df_cpy
# Out:
#       psychopath,empath  punchable,loveable  arrogant,humble  \
# A1                 55.5                31.0             51.7
# A4                 16.9                18.9             20.9
# AD1                75.3                51.9             45.9
# AD7                44.8                38.1             29.0
# AHX1               48.6                57.0             33.9
# ...                 ...                 ...              ...
# Y5                 51.3                68.8             63.5
# Y6                 89.2                69.3             85.3
# Y8                 41.4                29.3             25.8
# Y9                 66.8                70.0             68.9
# ZL1                32.4                54.0             22.5
#
#       selfish,altruistic  cruel,kind  vengeful,forgiving  quarrelsome,warm  \
# A1                  59.7        63.1                60.1              45.0
# A4                  29.4        26.2                27.5              25.1
# AD1                 61.5        68.2                64.9              40.4
# AD7                 40.8        77.5                73.0              64.4
# AHX1                25.0        48.1                60.2              19.7
# ...                  ...         ...                 ...               ...
# Y5                  69.0        53.2                17.6              29.1
# Y6                  77.2        83.0                57.6              74.1
# Y8                  37.7        31.6                17.7              33.6
# Y9                  79.5        72.2                44.5              51.0
# ZL1                 39.6        55.8                25.8              28.2
#
#       impatient,patient  juvenile,mature  entitled,grateful  ...  \
# A1                 48.6             73.3               34.7  ...
# A4                 61.8             74.4                7.7  ...
# AD1                55.0             72.8               38.0  ...
# AD7                46.0             14.8               32.0  ...
# AHX1               28.7             22.5               31.5  ...
# ...                 ...              ...                ...  ...
# Y5                 33.1             63.2               86.8  ...
# Y6                 72.0             80.6               70.2  ...
# Y8                 60.2             61.6               30.5  ...
# Y9                 70.0             77.5               76.8  ...
# ZL1                10.8             29.4               44.1  ...
#
#       chosen one,everyman  German,English  feminine,masculine  \
# A1                   71.4            75.4                86.1
# A4                   48.6            40.1                68.5
# AD1                  56.5            77.8                63.4
# AD7                  64.9            43.6                22.4
# AHX1                 36.1            42.5                70.2
# ...                   ...             ...                 ...
# Y5                   41.8            64.8                95.1
# Y6                   37.4            66.9                34.3
# Y8                   30.2            57.5                73.5
# Y9                   70.3            52.6                93.2
# ZL1                  49.2            77.7                93.1
#
#       avant-garde,classical  outsider,insider  industrial,domestic  \
# A1                     60.1              60.5                 29.6
# A4                     67.5              41.7                 15.4
# AD1                    75.1              44.1                 61.8
# AD7                    31.7              12.1                 82.1
# AHX1                   25.4              21.8                 47.2
# ...                     ...               ...                  ...
# Y5                     63.8              32.5                 40.1
# Y6                     69.6              19.9                 48.4
# Y8                     64.2              43.0                 56.7
# Y9                     74.6              42.3                 38.0
# ZL1                    36.5              18.3                 37.0
#
#       complicated,simple  literary,mathematical  slow,fast  careful,brave
# A1                  52.7                   65.8       53.0           57.8
# A4                  30.3                   87.7       63.3           26.2
# AD1                 44.0                   76.0       65.2           23.8
# AD7                 44.1                   24.8       18.9           37.1
# AHX1                22.2                   25.0       66.5           60.8
# ...                  ...                    ...        ...            ...
# Y5                  44.6                   61.4       79.4           93.4
# Y6                  35.5                   27.9       71.9           63.6
# Y8                   8.0                   49.4       63.8           27.7
# Y9                  76.4                   35.6       51.7           58.7
# ZL1                 45.6                   33.1       75.3           85.6
#
# [858 rows x 360 columns]

# %%
race_label = merged_df['race.label']

# %%
import imblearn
oversample = imblearn.over_sampling.RandomOverSampler(sampling_strategy='minority')

X_over, y_over = oversample.fit_resample(merged_df_cpy, race_label)

# %%
y_over
# Out:
# 0         asian
# 1         white
# 2         white
# 3         white
# 4         white
#          ...
# 1585    mideast
# 1586    mideast
# 1587    mideast
# 1588    mideast
# 1589    mideast
# Name: race.label, Length: 1590, dtype: object

# %%
from sklearn.linear_model import LassoCV, Ridge, RidgeClassifier, LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score
from sklearn.preprocessing import LabelEncoder

# For gender prediction, we remove the 'masculine' label
race_columns = list(traits_columns)
#race_columns.append('gender.label')

y_encoder = LabelEncoder()

X = X_over[race_columns].values
y = y_encoder.fit_transform(y_over)

evaluate_classifier('Race', 'Random Forest 2^8 estimators, Gini', RandomForestClassifier(n_estimators=2**8, criterion='gini'), X, y)
evaluate_classifier('Race', 'Random Forest 2^8 estimators, Entropy', RandomForestClassifier(n_estimators=2**8, criterion='entropy'), X, y)
evaluate_classifier('Race', 'Logistic Regression L2, 10000 iterations', LogisticRegression(penalty='l2', max_iter=10000), X, y)
evaluate_classifier('Race', 'Ridge Classifier, alpha 0.1 ', RidgeClassifier(alpha=0.1), X, y)
evaluate_classifier('Race', 'Decision Tree, vanilla ', DecisionTreeClassifier(), X, y)
# Out:
# Race Accuracy using Random Forest 2^8 estimators, Gini: 0.9208
# Race Accuracy using Random Forest 2^8 estimators, Entropy: 0.922
# Race Accuracy using Logistic Regression L2, 10000 iterations: 0.8887
# Race Accuracy using Ridge Classifier, alpha 0.1 : 0.8553
# Race Accuracy using Decision Tree, vanilla : 0.8553
